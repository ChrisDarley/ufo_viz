# %%
import pandas as pd
import os

# %%
location_raw = pd.read_csv('location_raw.csv', index_col='datetime', parse_dates=True, dtype={'County.FIPS':str})

# %%
main_fips_set = set(location_raw['County.FIPS'].unique())

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/ma'
             'ster/geojson-counties-fips.json') as response:
    counties = json.load(response)

# %%
keys_to_extract = ['STATE', 'COUNTY']

# %%
records = []
for item in counties.get('features'):
    base = item.get('properties')
    res = dict(filter(lambda item: item[0] in keys_to_extract, base.items()))
    records.append(res)

# %%
counties_fips = pd.DataFrame.from_records(records).assign(fips=lambda df_: df_.STATE+df_.COUNTY)

# %%
counties_fips_set = set(counties_fips['fips'])

# %%
len(counties_fips_set)
# Out:
# 3221

# %%
population_path = os.path.join(
    os.getcwd(),
    'pop_data/nhgis0002_csv/nhgis0002_ts_nominal_county.csv'
    )

# %%
population_df = pd.read_csv(
    population_path,
    dtype={'STATEFP':str, 'COUNTYFP':str})

# %%
pop_fips = (population_df
    # selecing rows that have both county and state codes present
    .loc[lambda df_: 
        (~df_['STATEFP'].isna()) & 
        (~df_['COUNTYFP'].isna())]
    # combining the codes into one fips code
    .assign(fips=lambda df_:
        df_['STATEFP']+df_['COUNTYFP'])
    # dropping District of Columbia(11) and Puerto Rico(72)
    .loc[lambda df_:
        ~df_['STATEFP'].isin(['11', '72'])]
    )

# %%
pop_fips_set = set(pop_fips['fips'].unique())

# %%
len(pop_fips_set.difference(main_fips_set))
# Out:
# 408

# %%
# pop_fips_set
# main_fips_set
# counties_fips_set

# %%
# Counties in main dataset not contained in the map subset
# Counties that may have changed
main_fips_set.difference(counties_fips_set)
# Out:
# {'02063', '02066', '02158', '46102'}

# %%
# Fips codes from population dataset not in counties dataset
# Some of these may be from counties that no longer exist or
# whose fips code has changed
pop_fips_set.difference(counties_fips_set)
# Out:
# {'02010',
#  '02030',
#  '02040',
#  '02062',
#  '02063',
#  '02066',
#  '02080',
#  '02120',
#  '02140',
#  '02158',
#  '02160',
#  '02190',
#  '02200',
#  '02201',
#  '02210',
#  '02231',
#  '02232',
#  '02250',
#  '02260',
#  '02280',
#  '12025',
#  '30113',
#  '32025',
#  '46001',
#  '46102',
#  '46131',
#  '46133',
#  '51055',
#  '51123',
#  '51129',
#  '51151',
#  '51189',
#  '51560',
#  '51780',
#  '56047'}

# %%
location_raw.loc[location_raw['County.FIPS'].isin(main_fips_set.difference(counties_fips_set))]
# Out:
#                                  city state country      shape   latitude
# datetime
# 1957-10-01 16:00:00   nelchina (near)    ak      us    unknown  61.991944  \
# 1969-07-05 10:53:00            valdez    ak      us       disk  61.130833
# 1974-11-15 09:00:00           cordova    ak      us       disk  60.542778
# 1980-08-05 23:15:00        glennallen    ak      us  rectangle  62.109167
# 1989-10-15 22:00:00        glennallen    ak      us    unknown  62.109167
# 1995-03-28 00:36:00           cordova    ak      us        NaN  60.542778
# 1996-03-02 00:30:00  mountain village    ak      us        NaN  62.085556
# 1999-07-04 21:00:00           arcadia    ca      us        NaN  34.139722
# 1999-07-04 21:00:00        pine ridge    sd      us      light  43.025556
# 2000-05-01 23:00:00  red shirt (near)    sd      us      light  43.667500
# 2001-12-15 00:00:00           cordova    ak      us     sphere  60.542778
# 2005-11-01 00:30:00        glennallen    ak      us    unknown  62.109167
# 2007-03-03 08:00:00            oglala    sd      us    unknown  43.188611
# 2010-06-26 23:00:00        pine ridge    sd      us      light  43.025556
# 2011-03-15 00:03:00        hooper bay    ak      us    unknown  61.531111
#
#                      comment_length  duration_seconds   longitude
# datetime
# 1957-10-01 16:00:00            24.0             180.0 -146.768611  \
# 1969-07-05 10:53:00             2.0            1020.0 -146.348333
# 1974-11-15 09:00:00            13.0               NaN -145.757500
# 1980-08-05 23:15:00             6.0            1500.0 -145.546389
# 1989-10-15 22:00:00            11.0               NaN -145.546389
# 1995-03-28 00:36:00            22.0             900.0 -145.757500
# 1996-03-02 00:30:00            21.0               NaN -163.729444
# 1999-07-04 21:00:00            25.0             480.0 -118.034444
# 1999-07-04 21:00:00            20.0              20.0 -102.555833
# 2000-05-01 23:00:00            16.0             180.0 -102.898333
# 2001-12-15 00:00:00             6.0             600.0 -145.757500
# 2005-11-01 00:30:00            10.0               NaN -145.546389
# 2007-03-03 08:00:00            22.0             600.0 -102.739167
# 2010-06-26 23:00:00            11.0               NaN -102.555833
# 2011-03-15 00:03:00            23.0             300.0 -166.096667
#
#                                                           query_string
# datetime
# 1957-10-01 16:00:00  https://geo.fcc.gov/api/census/block/find?lati...  \
# 1969-07-05 10:53:00  https://geo.fcc.gov/api/census/block/find?lati...
# 1974-11-15 09:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 1980-08-05 23:15:00  https://geo.fcc.gov/api/census/block/find?lati...
# 1989-10-15 22:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 1995-03-28 00:36:00  https://geo.fcc.gov/api/census/block/find?lati...
# 1996-03-02 00:30:00  https://geo.fcc.gov/api/census/block/find?lati...
# 1999-07-04 21:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 1999-07-04 21:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2000-05-01 23:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2001-12-15 00:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2005-11-01 00:30:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2007-03-03 08:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2010-06-26 23:00:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2011-03-15 00:03:00  https://geo.fcc.gov/api/census/block/find?lati...
#
#                                                                   json
# datetime
# 1957-10-01 16:00:00  {'Block': {'FIPS': '020660001001261', 'bbox': ...  \
# 1969-07-05 10:53:00  {'messages': ["FCC0001: The coordinate lies on...
# 1974-11-15 09:00:00  {'Block': {'FIPS': '020630002002015', 'bbox': ...
# 1980-08-05 23:15:00  {'Block': {'FIPS': '020660001001236', 'bbox': ...
# 1989-10-15 22:00:00  {'Block': {'FIPS': '020660001001236', 'bbox': ...
# 1995-03-28 00:36:00  {'Block': {'FIPS': '020630002002015', 'bbox': ...
# 1996-03-02 00:30:00  {'Block': {'FIPS': '021580001003091', 'bbox': ...
# 1999-07-04 21:00:00  {'Block': {'FIPS': '060374307211011', 'bbox': ...
# 1999-07-04 21:00:00  {'Block': {'FIPS': '461029410001139', 'bbox': ...
# 2000-05-01 23:00:00  {'Block': {'FIPS': '461029411001001', 'bbox': ...
# 2001-12-15 00:00:00  {'Block': {'FIPS': '020630002002015', 'bbox': ...
# 2005-11-01 00:30:00  {'Block': {'FIPS': '020660001001236', 'bbox': ...
# 2007-03-03 08:00:00  {'Block': {'FIPS': '461029411001092', 'bbox': ...
# 2010-06-26 23:00:00  {'Block': {'FIPS': '461029410001139', 'bbox': ...
# 2011-03-15 00:03:00  {'Block': {'FIPS': '021580001004076', 'bbox': ...
#
#                                                          selected_json status
# datetime
# 1957-10-01 16:00:00  {'Block': {'FIPS': '020660001001261', 'bbox': ...     OK  \
# 1969-07-05 10:53:00  {'Block': {'FIPS': '020630003001004', 'bbox': ...     OK
# 1974-11-15 09:00:00  {'Block': {'FIPS': '020630002002015', 'bbox': ...     OK
# 1980-08-05 23:15:00  {'Block': {'FIPS': '020660001001236', 'bbox': ...     OK
# 1989-10-15 22:00:00  {'Block': {'FIPS': '020660001001236', 'bbox': ...     OK
# 1995-03-28 00:36:00  {'Block': {'FIPS': '020630002002015', 'bbox': ...     OK
# 1996-03-02 00:30:00  {'Block': {'FIPS': '021580001003091', 'bbox': ...     OK
# 1999-07-04 21:00:00  {'Block': {'FIPS': '060374307211011', 'bbox': ...     OK
# 1999-07-04 21:00:00  {'Block': {'FIPS': '461029410001139', 'bbox': ...     OK
# 2000-05-01 23:00:00  {'Block': {'FIPS': '461029411001001', 'bbox': ...     OK
# 2001-12-15 00:00:00  {'Block': {'FIPS': '020630002002015', 'bbox': ...     OK
# 2005-11-01 00:30:00  {'Block': {'FIPS': '020660001001236', 'bbox': ...     OK
# 2007-03-03 08:00:00  {'Block': {'FIPS': '461029411001092', 'bbox': ...     OK
# 2010-06-26 23:00:00  {'Block': {'FIPS': '461029410001139', 'bbox': ...     OK
# 2011-03-15 00:03:00  {'Block': {'FIPS': '021580001004076', 'bbox': ...     OK
#
#                           Block.FIPS
# datetime
# 1957-10-01 16:00:00   20660001001261  \
# 1969-07-05 10:53:00   20630003001004
# 1974-11-15 09:00:00   20630002002015
# 1980-08-05 23:15:00   20660001001236
# 1989-10-15 22:00:00   20660001001236
# 1995-03-28 00:36:00   20630002002015
# 1996-03-02 00:30:00   21580001003091
# 1999-07-04 21:00:00  461029410001139
# 1999-07-04 21:00:00  461029410001139
# 2000-05-01 23:00:00  461029411001001
# 2001-12-15 00:00:00   20630002002015
# 2005-11-01 00:30:00   20660001001236
# 2007-03-03 08:00:00  461029411001092
# 2010-06-26 23:00:00  461029410001139
# 2011-03-15 00:03:00   21580001004076
#
#                                                            Block.bbox
# datetime
# 1957-10-01 16:00:00  [-146.947138, 61.949935, -146.680945, 62.026792]  \
# 1969-07-05 10:53:00  [-146.349969, 61.129133, -146.344487, 61.130852]
# 1974-11-15 09:00:00    [-145.7586, 60.542303, -145.757014, 60.543214]
# 1980-08-05 23:15:00  [-145.583228, 62.108621, -145.529862, 62.120348]
# 1989-10-15 22:00:00  [-145.583228, 62.108621, -145.529862, 62.120348]
# 1995-03-28 00:36:00    [-145.7586, 60.542303, -145.757014, 60.543214]
# 1996-03-02 00:30:00  [-163.732804, 62.085033, -163.722817, 62.090731]
# 1999-07-04 21:00:00   [-102.55642, 43.022061, -102.551761, 43.025903]
# 1999-07-04 21:00:00   [-102.55642, 43.022061, -102.551761, 43.025903]
# 2000-05-01 23:00:00   [-102.911143, 43.66737, -102.892154, 43.674908]
# 2001-12-15 00:00:00    [-145.7586, 60.542303, -145.757014, 60.543214]
# 2005-11-01 00:30:00  [-145.583228, 62.108621, -145.529862, 62.120348]
# 2007-03-03 08:00:00   [-102.750304, 43.15891, -102.681169, 43.209326]
# 2010-06-26 23:00:00   [-102.55642, 43.022061, -102.551761, 43.025903]
# 2011-03-15 00:03:00  [-166.103221, 61.529944, -166.093199, 61.532771]
#
#                     County.FIPS               County.name  State.FIPS
# datetime
# 1957-10-01 16:00:00       02066  Copper River Census Area           2  \
# 1969-07-05 10:53:00       02063       Chugach Census Area           2
# 1974-11-15 09:00:00       02063       Chugach Census Area           2
# 1980-08-05 23:15:00       02066  Copper River Census Area           2
# 1989-10-15 22:00:00       02066  Copper River Census Area           2
# 1995-03-28 00:36:00       02063       Chugach Census Area           2
# 1996-03-02 00:30:00       02158      Kusilvak Census Area           2
# 1999-07-04 21:00:00       46102      Oglala Lakota County          46
# 1999-07-04 21:00:00       46102      Oglala Lakota County          46
# 2000-05-01 23:00:00       46102      Oglala Lakota County          46
# 2001-12-15 00:00:00       02063       Chugach Census Area           2
# 2005-11-01 00:30:00       02066  Copper River Census Area           2
# 2007-03-03 08:00:00       46102      Oglala Lakota County          46
# 2010-06-26 23:00:00       46102      Oglala Lakota County          46
# 2011-03-15 00:03:00       02158      Kusilvak Census Area           2
#
#                     State.code    State.name
# datetime
# 1957-10-01 16:00:00         AK        Alaska
# 1969-07-05 10:53:00         AK        Alaska
# 1974-11-15 09:00:00         AK        Alaska
# 1980-08-05 23:15:00         AK        Alaska
# 1989-10-15 22:00:00         AK        Alaska
# 1995-03-28 00:36:00         AK        Alaska
# 1996-03-02 00:30:00         AK        Alaska
# 1999-07-04 21:00:00         SD  South Dakota
# 1999-07-04 21:00:00         SD  South Dakota
# 2000-05-01 23:00:00         SD  South Dakota
# 2001-12-15 00:00:00         AK        Alaska
# 2005-11-01 00:30:00         AK        Alaska
# 2007-03-03 08:00:00         SD  South Dakota
# 2010-06-26 23:00:00         SD  South Dakota
# 2011-03-15 00:03:00         AK        Alaska

# %%
location_raw.columns
# Out:
# Index(['city', 'state', 'country', 'shape', 'latitude', 'comment_length',
#        'duration_seconds', 'longitude', 'query_string', 'json',
#        'selected_json', 'status', 'Block.FIPS', 'Block.bbox', 'County.FIPS',
#        'County.name', 'State.FIPS', 'State.code', 'State.name'],
#       dtype='object')

# %%
# puerto rico
main_fips_set.difference(pop_fips_set)
# Out:
# {'11001',
#  '72013',
#  '72015',
#  '72019',
#  '72029',
#  '72055',
#  '72071',
#  '72077',
#  '72079',
#  '72081',
#  '72097',
#  '72099',
#  '72113',
#  '72117',
#  '72119',
#  '72127',
#  '72129',
#  '72139',
#  '72141',
#  '72143',
#  '72145'}

# %%
len(pop_fips_set.difference(main_fips_set))
# Out:
# 408

# %%
(location_raw['County.FIPS']=='1101').sum()
# Out:
# 0

# %%
location_raw[location_raw['County.FIPS'] =='11001']
# Out:
#                            city state country     shape   latitude
# datetime
# 2010-08-28 22:06:00  washington    dc      us  fireball  38.895000  \
# 2011-06-15 20:19:00  georgetown    dc      us      disk  38.904722
# 2011-12-11 20:08:00  washington    dc      us  cylinder  38.895000
# 2012-01-29 19:20:00  washington    dc      us     other  38.895000
# 2012-07-04 21:06:00  washington    dc      us    sphere  38.895000
# 2012-07-25 21:30:00  washington    dc      us  changing  38.895000
# 2012-08-09 03:00:00  washington    dc      us     light  38.895000
#
#                      comment_length  duration_seconds  longitude
# datetime
# 2010-08-28 22:06:00            11.0             120.0 -77.036667  \
# 2011-06-15 20:19:00            15.0               6.0 -77.062778
# 2011-12-11 20:08:00             7.0               4.0 -77.036667
# 2012-01-29 19:20:00            17.0              10.0 -77.036667
# 2012-07-04 21:06:00             9.0               5.5 -77.036667
# 2012-07-25 21:30:00            23.0             900.0 -77.036667
# 2012-08-09 03:00:00             7.0             600.0 -77.036667
#
#                                                           query_string
# datetime
# 2010-08-28 22:06:00  https://geo.fcc.gov/api/census/block/find?lati...  \
# 2011-06-15 20:19:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2011-12-11 20:08:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2012-01-29 19:20:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2012-07-04 21:06:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2012-07-25 21:30:00  https://geo.fcc.gov/api/census/block/find?lati...
# 2012-08-09 03:00:00  https://geo.fcc.gov/api/census/block/find?lati...
#
#                                                                   json
# datetime
# 2010-08-28 22:06:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...  \
# 2011-06-15 20:19:00  {'messages': ["FCC0001: The coordinate lies on...
# 2011-12-11 20:08:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...
# 2012-01-29 19:20:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...
# 2012-07-04 21:06:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...
# 2012-07-25 21:30:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...
# 2012-08-09 03:00:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...
#
#                                                          selected_json status
# datetime
# 2010-08-28 22:06:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...     OK  \
# 2011-06-15 20:19:00  {'Block': {'FIPS': '110010001023013', 'bbox': ...     OK
# 2011-12-11 20:08:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...     OK
# 2012-01-29 19:20:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...     OK
# 2012-07-04 21:06:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...     OK
# 2012-07-25 21:30:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...     OK
# 2012-08-09 03:00:00  {'Block': {'FIPS': '110019800001037', 'bbox': ...     OK
#
#                           Block.FIPS
# datetime
# 2010-08-28 22:06:00  110019800001037  \
# 2011-06-15 20:19:00  110010001023013
# 2011-12-11 20:08:00  110019800001037
# 2012-01-29 19:20:00  110019800001037
# 2012-07-04 21:06:00  110019800001037
# 2012-07-25 21:30:00  110019800001037
# 2012-08-09 03:00:00  110019800001037
#
#                                                         Block.bbox
# datetime
# 2010-08-28 22:06:00  [-77.038489, 38.892609, -77.03462, 38.895201]  \
# 2011-06-15 20:19:00  [-77.062811, 38.904709, -77.061176, 38.90519]
# 2011-12-11 20:08:00  [-77.038489, 38.892609, -77.03462, 38.895201]
# 2012-01-29 19:20:00  [-77.038489, 38.892609, -77.03462, 38.895201]
# 2012-07-04 21:06:00  [-77.038489, 38.892609, -77.03462, 38.895201]
# 2012-07-25 21:30:00  [-77.038489, 38.892609, -77.03462, 38.895201]
# 2012-08-09 03:00:00  [-77.038489, 38.892609, -77.03462, 38.895201]
#
#                     County.FIPS           County.name  State.FIPS State.code
# datetime
# 2010-08-28 22:06:00       11001  District of Columbia          11         DC  \
# 2011-06-15 20:19:00       11001  District of Columbia          11         DC
# 2011-12-11 20:08:00       11001  District of Columbia          11         DC
# 2012-01-29 19:20:00       11001  District of Columbia          11         DC
# 2012-07-04 21:06:00       11001  District of Columbia          11         DC
# 2012-07-25 21:30:00       11001  District of Columbia          11         DC
# 2012-08-09 03:00:00       11001  District of Columbia          11         DC
#
#                                State.name
# datetime
# 2010-08-28 22:06:00  District of Columbia
# 2011-06-15 20:19:00  District of Columbia
# 2011-12-11 20:08:00  District of Columbia
# 2012-01-29 19:20:00  District of Columbia
# 2012-07-04 21:06:00  District of Columbia
# 2012-07-25 21:30:00  District of Columbia
# 2012-08-09 03:00:00  District of Columbia

# %%
counties_fips[counties_fips['fips']=='11001']
# Out:
#     STATE COUNTY   fips
# 792    11    001  11001

# %%
counties_fips[counties_fips['STATE']=='11']
# Out:
#     STATE COUNTY   fips
# 792    11    001  11001
